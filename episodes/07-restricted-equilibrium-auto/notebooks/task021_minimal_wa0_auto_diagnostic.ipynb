# %% [markdown]
# # TASK-021 minimal AUTO W_a0 diagnostic
#
# This notebook records the exact AUTO commands used for the stripped restricted/scaled W_a0 diagnostic. It keeps TASK-021 artifacts separate from TASK-017.

# %%
import os, subprocess
from pathlib import Path
AUTO_DIR = Path("../auto/berton_restricted_task021_minimal").resolve()
AUTO_DIR

# %% [markdown]
# ## AUTO run
#
# Constants are in `c.bertonrestricted-task021-minimal-wA0-{plus,minus}`: `ICP=['W_a0']`, `ISP=0`, `ILP=0`, `JAC=0`, `NPAR=53`, empty `PVLS`. The exact AUTO command stream is in `run_auto.sh`.

# %%
cmd = ["bash", str(AUTO_DIR / "run_auto.sh")]
# subprocess.run(cmd, check=True)  # uncomment to rerun AUTO from this notebook
print(" ".join(cmd))

# %% [markdown]
# ## Parse curated outputs

# %%
parse_cmd = ["uv", "run", "python", "../scripts/berton_restricted_task021_minimal_auto.py"]
# subprocess.run(parse_cmd, check=True, cwd=Path("..").resolve().parents[1])  # repository root
print(" ".join(parse_cmd))
